# %%
ord('牛')
# Out:
# 29275

# %%
chr(29233)
# Out:
# '爱'

# %%
chr(0)
# Out:
# '\x00'

# %%
print(chr(0))

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
test_string = "hello! こんにちは!"
utf8_encode = test_string.encode("utf-8")
print(utf8_encode)
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'

# %%
print(type(utf8_encode))
# Out:
# <class 'bytes'>

# %%
list(utf8_encode)
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
print(len(utf8_encode))
# Out:
# 23

# %%
print(len(test_string))
# Out:
# 13

# %%
print(utf8_encode.decode("utf8"))
# Out:
# hello! こんにちは!

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes[b].decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
#
# Cell In[35], line 2, in decode_utf8_bytes_to_str_wrong(bytestring)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2     return "".join([bytes[b].decode("utf-8") for b in bytestring])
#
# Cell In[35], line 2, in <listcomp>(.0)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2     return "".join([bytes[b].decode("utf-8") for b in bytestring])
#
# TypeError: type 'bytes' is not subscriptable
